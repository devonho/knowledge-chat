# %%
import pandas as pd
from datetime import datetime
from neo4j import GraphDatabase, RoutingControl

# %% [markdown]
# # Extract & Transform

# %%
df_org = pd.read_csv("../data/car_prices.csv")
df_org = df_org.dropna(subset=["saledate"])

def xfm(r):
    saledate = float("nan")
    try:
        saledate = datetime.strptime(r["saledate"][:-6],"%a %b %d %Y %H:%M:%S GMT%z")
    except ValueError:
        pass
    r["saledate"] = saledate
    return r
df_org = df_org.apply(xfm, axis=1)
df_org = df_org.dropna()

# %%
df_org.head(3)
# Out:
#    year make     model        trim   body transmission                vin  \
# 0  2015  Kia   Sorento          LX    SUV    automatic  5xyktca69fg566472
# 1  2015  Kia   Sorento          LX    SUV    automatic  5xyktca69fg561319
# 2  2014  BMW  3 Series  328i SULEV  Sedan    automatic  wba3c1c51ek116351
#
#   state  condition  odometer  color interior  \
# 0    ca        5.0   16639.0  white    black
# 1    ca        5.0    9393.0  white    beige
# 2    ca       45.0    1331.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
#
#                     saledate
# 0  2014-12-16 12:30:00-08:00
# 1  2014-12-16 12:30:00-08:00
# 2  2015-01-15 04:30:00-08:00

# %% [markdown]
# # Load

# %%
URI = "neo4j://localhost:7687"
AUTH = ("neo4j", "neo4j!!!!")

# %%
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    for tup in df_org.iterrows():
        r = tup[1]
        model_year = r["year"]
        make = r["make"]
        model = r["model"]
        trim = r["trim"]
        body = r["body"]
        transmission = r["transmission"]
        vin = r["vin"]
        odometer = r["odometer"]
        extcolor = r["color"]
        intcolor = r["interior"]
        seller = r["seller"]
        mmr = r["mmr"]
        sellingprice = r["sellingprice"]
        saledate = r["saledate"]
        
        driver.execute_query(
            "MERGE (v:Vehicle {vin: $vin, trim: $trim, odometer:$odometer, exterior_color:$extcolor, interior_color:$intcolor, mmr:$mmr, sellingprice:$sellingprice, saledate:$saledate}) "
            "MERGE (mk:Maker {maker: $make}) "
            "MERGE (mdl:Model {model: $model}) "
            "MERGE (bd:Body {body: $body}) "
            "MERGE (tx:Transmission {transmission: $transmission})"
            "MERGE (s:Seller {seller: $seller}) "
            
            "MERGE (mk)-[:MADE]->(v)"
            "MERGE (v)-[:IS_A]->(mdl)"
            "MERGE (mdl)-[:IS_A]->(bd)"
            "MERGE (v)-[:HAS_TRANSMISSION]->(tx)"
            "MERGE (s)-[:SOLD]->(v)",
            
            model_year=model_year,
            make=make,
            model=model,
            trim=trim,
            body=body,
            transmission=transmission,
            vin=vin,
            odometer=odometer,
            extcolor=extcolor,
            intcolor=intcolor,
            seller=seller,
            mmr=mmr,
            sellingprice=sellingprice,
            saledate=saledate,            
            database_="neo4j",
        )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[110], line 19
#      16 sellingprice = r["sellingprice"]
#      17 saledate = r["saledate"]
# ---> 19 driver.execute_query(
#      20     "MERGE (v:Vehicle {vin: $vin, trim: $trim, odometer:$odometer, exterior_color:$extcolor, interior_color:$intcolor, mmr:$mmr, sellingprice:$sellingprice, saledate:$saledate}) "
#      21     "MERGE (mk:Maker {maker: $make}) "
#      22     "MERGE (mdl:Model {model: $model}) "
#      23     "MERGE (bd:Body {body: $body}) "
#      24     "MERGE (tx:Transmission {transmission: $transmission})"
#      25     "MERGE (s:Seller {seller: $seller}) "
#      26
#      27     "MERGE (mk)-[:MADE]->(v)"
#      28     "MERGE (v)-[:IS_A]->(mdl)"
#      29     "MERGE (mdl)-[:IS_A]->(bd)"
#      30     "MERGE (v)-[:HAS_TRANSMISSION]->(tx)"
#      31     "MERGE (s)-[:SOLD]->(v)",
#      32
#      33     model_year=model_year,
#      34     make=make,
#      35     model=model,
#      36     trim=trim,
#      37     body=body,
#      38     transmission=transmission,
#      39     vin=vin,
#      40     odometer=odometer,
#      41     extcolor=extcolor,
#      42     intcolor=intcolor,
#      43     seller=seller,
#      44     mmr=mmr,
#      45     sellingprice=sellingprice,
#      46     saledate=saledate,
#      47     database_="neo4j",
#      48 )
#
# File ~/.virtualenvs/neo4j/lib/python3.12/site-packages/neo4j/_sync/driver.py:970, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     966     raise ValueError(
#     967         f"Invalid routing control value: {routing_!r}"
#     968     )
#     969 with session._pipelined_begin:
# --> 970     return session._run_transaction(
#     971         access_mode,
#     972         TelemetryAPI.DRIVER,
#     973         work,
#     974         (query_str, parameters, result_transformer_),
#     975         {},
#     976     )
#
# File ~/.virtualenvs/neo4j/lib/python3.12/site-packages/neo4j/_sync/work/session.py:572, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     570 while True:
#     571     try:
# --> 572         self._open_transaction(
#     573             tx_cls=ManagedTransaction,
#     574             api=None if telemetry_sent else api,
#     575             access_mode=access_mode,
#     576             metadata=metadata,
#     577             timeout=timeout,
#     578             api_success_cb=api_success_cb,
#     579         )
#     580         assert isinstance(self._transaction, ManagedTransaction)
#     581         tx = self._transaction
#
# File ~/.virtualenvs/neo4j/lib/python3.12/site-packages/neo4j/_sync/work/session.py:441, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     431 def _open_transaction(
#     432     self,
#     433     *,
#    (...)    439     api_success_cb: t.Callable[[dict], None] | None = None,
#     440 ) -> None:
# --> 441     self._connect(access_mode=access_mode)
#     442     assert self._connection is not None
#     443     if api is not None:
#
# File ~/.virtualenvs/neo4j/lib/python3.12/site-packages/neo4j/_sync/work/session.py:136, in Session._connect(self, access_mode, **acquire_kwargs)
#     134     access_mode = self._config.default_access_mode
#     135 try:
# --> 136     super()._connect(
#     137         access_mode, auth=self._config.auth, **acquire_kwargs
#     138     )
#     139 except asyncio.CancelledError:
#     140     self._handle_cancellation(message="_connect")
#
# File ~/.virtualenvs/neo4j/lib/python3.12/site-packages/neo4j/_sync/work/workspace.py:199, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     189 acquire_kwargs_ = {
#     190     "access_mode": access_mode,
#     191     "timeout": acquisition_timeout,
#    (...)    196     "database_callback": self._make_db_resolution_callback(),
#     197 }
#     198 acquire_kwargs_.update(acquire_kwargs)
# --> 199 self._connection = self._pool.acquire(**acquire_kwargs_)
#     200 if (
#     201     target_db.guessed
#     202     and not self._pinned_database
#    (...)    206     # support SSR.
#     207     # => we need to fall back to explicit home database resolution
#     208     log.debug(
#     209         "[#0000]  _: <WORKSPACE> detected ssr support race; "
#     210         "falling back to explicit home database resolution",
#     211     )
#
# File ~/.virtualenvs/neo4j/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:1179, in Neo4jPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, database_callback)
#    1175 while True:
#    1176     try:
#    1177         # Get an address for a connection that have the fewest in-use
#    1178         # connections.
# -> 1179         address = self._select_address(
#    1180             access_mode=access_mode, database=target_database
#    1181         )
#    1182     except (ReadServiceUnavailable, WriteServiceUnavailable) as err:
#    1183         raise SessionExpired(
#    1184             f"Failed to obtain connection towards '{access_mode}' "
#    1185             "server."
#    1186         ) from err
#
# File ~/.virtualenvs/neo4j/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:1109, in Neo4jPool._select_address(self, access_mode, database)
#    1107         addresses = ()
#    1108     addresses_by_usage = {}
# -> 1109     for address in addresses:
#    1110         addresses_by_usage.setdefault(
#    1111             self.in_use_connection_count(address), []
#    1112         ).append(address)
#    1113 if not addresses_by_usage:
#
# File ~/.virtualenvs/neo4j/lib/python3.12/site-packages/neo4j/_routing.py:40, in OrderedSet.__iter__(self)
#      37 def __contains__(self, element):
#      38     return element in self._elements
# ---> 40 def __iter__(self):
#      41     return iter(self._elements)
#      43 def __len__(self):
#
# KeyboardInterrupt:
